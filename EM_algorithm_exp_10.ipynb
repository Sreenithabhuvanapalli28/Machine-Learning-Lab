# %% [markdown]
# <a href="https://colab.research.google.com/github/Sreenithabhuvanapalli28/Machine-Learning-Lab/blob/main/EM_algorithm_exp_10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np, matplotlib.pyplot as plt
from sklearn.datasets import make_blobs
from sklearn.mixture import GaussianMixture

X, _ = make_blobs(n_samples=300, centers=3, random_state=42)

gmm = GaussianMixture(n_components=3, random_state=42)
gmm.fit(X)
labels = gmm.predict(X)

print("Means:\n", gmm.means_)
print("Covariances:\n", gmm.covariances_)

plt.scatter(X[:,0], X[:,1], c=labels)
plt.title("EM Clustering using GMM")
plt.show()
# Out:
# Means:
#  [[-2.63323268  9.04356978]
#  [-6.88387179 -6.98398415]
#  [ 4.74710337  2.01059427]]
# Covariances:
#  [[[ 0.74869031  0.04368399]
#   [ 0.04368399  0.98715159]]
#
#  [[ 1.02961821  0.09574043]
#   [ 0.09574043  0.98277206]]
#
#  [[ 1.07033552 -0.09844297]
#   [-0.09844297  0.85003382]]]
