# %% [markdown]
# <a href="https://colab.research.google.com/github/Sreenithabhuvanapalli28/Machine-Learning-Lab/blob/main/Find_s_exp1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

data = {
    "Sky": ["Sunny", "Sunny", "Rainy", "Sunny"],
    "AirTemp": ["Warm", "Warm", "Cold", "Warm"],
    "Humidity": ["Normal", "High", "High", "High"],
    "Wind": ["Strong", "Strong", "Strong", "Strong"],
    "Forecast": ["Same", "Same", "Change", "Same"],
    "EnjoySport": ["Yes", "Yes", "No", "Yes"]
}

df = pd.DataFrame(data)
hypothesis = ['0'] * (len(df.columns) - 1)
print("Initial Hypothesis:", hypothesis)

for i, row in df.iterrows():
    if row["EnjoySport"] == "Yes":
        for j in range(len(hypothesis)):
            if hypothesis[j] == '0':
                hypothesis[j] = row.iloc[j]
            elif hypothesis[j] != row.iloc[j]:
                hypothesis[j] = '?'
    print(f"After instance {i+1}: {hypothesis}")

print("Final Hypothesis:", hypothesis)
# Out:
# Initial Hypothesis: ['0', '0', '0', '0', '0']
# After instance 1: ['Sunny', 'Warm', 'Normal', 'Strong', 'Same']
# After instance 2: ['Sunny', 'Warm', '?', 'Strong', 'Same']
# After instance 3: ['Sunny', 'Warm', '?', 'Strong', 'Same']
# After instance 4: ['Sunny', 'Warm', '?', 'Strong', 'Same']
# Final Hypothesis: ['Sunny', 'Warm', '?', 'Strong', 'Same']
