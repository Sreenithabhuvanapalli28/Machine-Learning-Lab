# %% [markdown]
# <a href="https://colab.research.google.com/github/Sreenithabhuvanapalli28/Machine-Learning-Lab/blob/main/decision_tree_exp_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from sklearn.tree import DecisionTreeClassifier, plot_tree
import matplotlib.pyplot as plt

# Sample dataset
data = {
    'Outlook': [0, 0, 1, 2, 2, 2, 1, 0],
    'Temperature': [0, 0, 0, 1, 1, 1, 1, 0],
    'Humidity': [1, 1, 1, 1, 0, 0, 0, 1],
    'Wind': [0, 1, 0, 0, 0, 1, 1, 0],
    'PlayTennis': [0, 0, 1, 1, 1, 0, 1, 0]
}

df = pd.DataFrame(data)

X = df.drop('PlayTennis', axis=1)
y = df['PlayTennis']

# ID3 uses entropy
model = DecisionTreeClassifier(criterion='entropy')
model.fit(X, y)

# Plot tree
plt.figure(figsize=(8,5))
plot_tree(model, feature_names=X.columns, class_names=['No','Yes'], filled=True)
plt.show()

# Test sample
test = [[0, 1, 1, 0]]
print("Prediction:", model.predict(test))
# Out:
# Prediction: [0]
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
